# %%
import pandas

df = pandas.read_csv("../../data/kaggle_housing_prices/train.csv")
df[["YrSold", "SalePrice"]].groupby(["YrSold"]).mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='YrSold'>
